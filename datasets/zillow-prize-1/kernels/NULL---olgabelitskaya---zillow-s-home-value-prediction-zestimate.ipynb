# %% [markdown]
# # &#x1F4D1; &nbsp; Zillow’s Home Value Prediction (Zestimate)

# %% [markdown]
# ## Links

# %% [markdown]
# ## Libraries

# %%
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
import numpy as np 
import pandas as pd 

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pylab as plt
import matplotlib.cm as cm

# %matplotlib inline

# %% [markdown]
# ## Data

# %%
df_train_2016 = pd.read_csv("../input/train_2016_v2.csv")
df_properties_2016 = pd.read_csv("../input/properties_2016.csv")

# %%
df_train_2016.shape

# %%
df_properties_2016.shape

# %%
df_train_2016.head(3)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(14, 7))

plt.plot(df_train_2016['logerror'])

plt.ylabel("Logerror")
plt.title('Zillow’s Home Value Prediction');

# %%
df_properties_2016.ix[:,25:45].head(5).T

# %%
df_properties_2016.isnull().sum()
