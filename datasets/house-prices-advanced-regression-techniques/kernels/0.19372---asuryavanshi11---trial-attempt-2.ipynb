# %% [markdown]
# We're starting with Acquiring the training and testing data and combining them(for further use).

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Read the data
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

train_y = train.SalePrice
predictor_cols = ['LotArea', 'OverallQual', 'YearBuilt', 'TotRmsAbvGrd']
train_X = train[predictor_cols]
test_X = test[predictor_cols]
#combine the training and testing data
combine = [train, test]

# %% [markdown]
# # Handling missing data
#
# We are dropping the columns with missing values here.

# %%
cols_with_missing = [col for col in train_X.columns 
                                 if train_X[col].isnull().any()]
reduced_train_X = train_X.drop(cols_with_missing, axis=1)
reduced_test_X  = test_X.drop(cols_with_missing, axis=1)

# %% [markdown]
# # Data description
#
# In this  section, we're describing the data for better analysis of data i.e. to know if the data is categorical or numerical or mixed.
# The code sections below will tell how many data columns are integer type, how many are float type and how many are object type or categorical type.

# %% [markdown]
# This will tell about the columns i.e. what data do they store.

# %%
print(reduced_train_X.columns.values)

# %% [markdown]
# # Modelling
#
# Here, we're using Random Forest regressor for the modelling purpose. You can use any model.

# %% [markdown]
# In addition to your training data, there will be test data. This is frequently stored in a file with the title `test.csv`. This data won't include a column with your target (y), because that is what we'll have to predict and submit.  Here is sample code to do that.

# %%
#random forest
my_model = RandomForestRegressor()
my_model.fit(reduced_train_X, train_y)

# Treat the test data in the same way as training data. In this case, pull same columns.


# Use the model to make predictions
predicted_prices = my_model.predict(reduced_test_X)

# We will look at the predicted prices to ensure we have something sensible.
print(predicted_prices)

# %% [markdown]
# # Accuracy
#
# This section is to know  the accuracy of your model.

# %%
acc_my_model = round(my_model.score(train_X, train_y) * 100, 2)
acc_my_model

# %% [markdown]
# # Prepare Submission File
# We make submissions in CSV files.  Your submissions usually have two columns: an ID column and a prediction column.  The ID field comes from the test data (keeping whatever name the ID field had in that data, which for the housing data is the string 'Id'). The prediction column will use the name of the target field.
#
# We will create a DataFrame with this data, and then use the dataframe's `to_csv` method to write our submission file.  Explicitly include the argument `index=False` to prevent pandas from adding another column in our csv file.

# %%
my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predicted_prices})
# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)
