# %% [markdown]
# In this notebook I'll try to figure out how the public test set is comparable with the train dataset. By many submissions, I'll obtain the repartition of labels in the public test set.
#
# So far I've done:
#
#
# | label         	|yes	|	no	|	up	|	down	|	left	|	right	|	on	|	off	|	stop	|	go	|	silence	|	unknown
# |---------------	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|
# | % in test set 	|  0.08 	|   0.07	|   0.08	|  0.06|   0.08	|   	|   	|   	|   	|   	|   	|   0.09	|

# %% [markdown]
# ## Benchmark

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

BENCHMARK_LABEL = 'right'
sample_submission = pd.read_csv('../input/sample_submission.csv', index_col='fname')
sample_submission['label'] = BENCHMARK_LABEL
sample_submission.to_csv(BENCHMARK_LABEL + '_is_golden.csv')

# %%
sample_submission.head()
