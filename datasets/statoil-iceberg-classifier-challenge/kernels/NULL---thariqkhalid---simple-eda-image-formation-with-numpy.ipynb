# %% [markdown]
# ## This is a simple EDA with numpy on how to extract the images from the given files. You can understand how some of the numpy functions work for data preparation through this notebook. I hope it helps!

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

import json
import matplotlib.pyplot as plt
from skimage import color

# Any results you write to the current directory are saved as output.

# %% [markdown]
# Read the data

# %%
data = pd.read_json("../input/train.json")
data.head()

# %% [markdown]
# Read from dataframe to numpy arrays using vstack

# %%
HH = np.asarray(np.vstack(data.band_1.values))
HV = np.asarray(np.vstack(data.band_2.values))
HB = HH/HV

# %% [markdown]
# Convert them to RGB by normalizing the bands

# %%
def normalize(v):
    minv = np.min(v)
    maxv = np.max(v)
    res = (v-minv)/(maxv-minv)
    return res

R = normalize(HH)
G = normalize(HV)
B = normalize(HB)

print(R.shape, G.shape, B.shape)

# %% [markdown]
# stack the labels too!

# %%
label = np.asarray(np.vstack(data.is_iceberg.values))

# %% [markdown]
# now hstack R,G,B matrices to get all the channels stacked and then reshape and transpose to get proper images

# %%
ims_h = np.hstack((R,G,B))
ims = ims_h.reshape(1604,3,75,75).transpose(0,2,3,1).astype("float")
ims.shape

# %% [markdown]
# lets see and image with the label!
# First we'll convert the images into grayscale for simplified computing

# %%
def displayimage(ims, id):
    plt.imshow(ims[id],cmap='inferno')
    plt.grid(False)
    plt.title(data.is_iceberg[id])
    plt.show()
    
gims = color.rgb2gray(ims)
displayimage(gims,10)

# %% [markdown]
# # To be continued with traning details :)
