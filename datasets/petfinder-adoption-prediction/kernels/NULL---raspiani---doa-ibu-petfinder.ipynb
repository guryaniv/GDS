# %%
#masukan modul 7yang diperlukan 
import pandas as pd 
import numpy as np

# %%
data_train = pd.read_csv("../input/train/train.csv")
data_train.head()

# %%
data_breed_labels = pd.read_csv("../input/breed_labels.csv")
data_breed_labels.head()
