# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

print(os.listdir("../input"))

# %%
application_train = pd.read_csv('../input/application_train.csv')
POS_CASH_balance = pd.read_csv('../input/POS_CASH_balance.csv')
bureau_balance = pd.read_csv('../input/bureau_balance.csv')
previous_application = pd.read_csv('../input/previous_application.csv')
installments_payments = pd.read_csv('../input/installments_payments.csv')
credit_card_balance = pd.read_csv('../input/credit_card_balance.csv')
bureau = pd.read_csv('../input/bureau.csv')
application_test = pd.read_csv('../input/application_test.csv')

# %%
print(application_train.shape)
application_train.head()

# %%
print(POS_CASH_balance.shape)
POS_CASH_balance.head()

# %%
print(bureau_balance.shape)
bureau_balance.head()

# %%
print(previous_application.shape)
previous_application.head()

# %%
print(installments_payments.shape)
installments_payments.head()

# %%
print(credit_card_balance.shape)
credit_card_balance.head()

# %%
print(bureau.shape)
bureau.head()

# %%
total = application_train.isnull().sum().sort_values(ascending=False)
percent = (application_train.isnull().sum()/application_train.isnull().count()*100).sort_values(ascending=False)
missing_application_train_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_application_train_data.head(25)

# %%
total = POS_CASH_balance.isnull().sum().sort_values(ascending=False)
percent = (POS_CASH_balance.isnull().sum()/POS_CASH_balance.isnull().count()*100).sort_values(ascending=False)
missing_POS_CASH_balance_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_POS_CASH_balance_data.head(3)

# %%
total = bureau_balance.isnull().sum().sort_values(ascending = False)
percent = (bureau_balance.isnull().sum()/bureau_balance.isnull().count()*100).sort_values(ascending = False)
missing_bureau_balance_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_bureau_balance_data.head(3)

# %%
total = previous_application.isnull().sum().sort_values(ascending = False)
percent = (previous_application.isnull().sum()/previous_application.isnull().count()*100).sort_values(ascending = False)
missing_previous_application_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_previous_application_data.head(15)

# %%
total = installments_payments.isnull().sum().sort_values(ascending = False)
percent = (installments_payments.isnull().sum()/installments_payments.isnull().count()*100).sort_values(ascending = False)
missing_installments_payments_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_installments_payments_data.head(3)

# %%
total = credit_card_balance.isnull().sum().sort_values(ascending = False)
percent = (credit_card_balance.isnull().sum()/credit_card_balance.isnull().count()*100).sort_values(ascending = False)
missing_credit_card_balance_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_credit_card_balance_data.head(10)

# %%
total = bureau.isnull().sum().sort_values(ascending = False)
percent = (bureau.isnull().sum()/bureau.isnull().count()*100).sort_values(ascending = False)
missing_bureau_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_bureau_data.head(8)

# %%
df_repayed = application_train[application_train['TARGET']==0]
df_not_repayed = application_train[application_train['TARGET']==1]
plt.figure(figsize=(15,8))
plt.title("Distribution of AMT_CREDIT\n", fontsize=25)
sns.kdeplot(df_not_repayed["AMT_CREDIT"], shade=True, label='Not repayed')
sns.kdeplot(df_repayed["AMT_CREDIT"], shade=True, label='Repayed')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of AMT_INCOME_TOTAL")
ax = sns.kdeplot(application_train["AMT_INCOME_TOTAL"], shade=True)

# %%
import plotly.offline as py
import plotly.graph_objs as go

import cufflinks as cf
cf.go_offline()

name_type_suite = application_train["NAME_TYPE_SUITE"].value_counts()

trace = go.Bar(
    x = name_type_suite.index,
    y = (name_type_suite / name_type_suite.sum())*100,
)

data = [trace]

layout = go.Layout(
    title = "Who accompanied client when applying for the loan in % ",
    titlefont=dict(
        size=20,
        color='rgb(107, 107, 107)'
    ),
    yaxis=dict(
        title='Type of the Suite in %',
        titlefont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
name_type_suite = application_train["NAME_TYPE_SUITE"].value_counts()

plt.figure(figsize=(15,8))
sns.set(font_scale=2)
sns.set_style('whitegrid')
g = sns.barplot(name_type_suite.index, (name_type_suite / name_type_suite.sum())*100)
g.set_title("Who accompanied client when applying for the loan in % \n", fontsize=30)
g.set_xticklabels(name_type_suite.index, rotation=-75)
g.set_ylabel("Type of the Suite in %\n")

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x="NAME_TYPE_SUITE", data=application_train, hue="TARGET", order=name_type_suite.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Type of the suite in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Suite Type", fontsize=20)

# %%
target = application_train["TARGET"].value_counts()

df = pd.DataFrame({'Labels': target.index, 'Values': target.values})
df.iplot(kind='pie', labels='Labels', values='Values', title='Loan Repayed or not', hole=0.5)

# %%
name_contract_type = application_train["NAME_CONTRACT_TYPE"].value_counts()

plt.figure(figsize=(15,8))
sns.set(font_scale=2)
sns.set_style('whitegrid')
g = sns.barplot(name_contract_type.index, (name_contract_type/name_contract_type.sum())*100, palette='viridis')
g.set_title("Contract Type\n", fontsize=30)
g.set_ylabel("Percent %\n")

# %%
trace = go.Pie(
    labels=name_contract_type.index,
    values=name_contract_type,
    hole= 0.5
)
data = [trace]

layout = go.Layout(
    title = "Contract Type",
    titlefont=dict(
        size=20
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
sns.set_style("whitegrid")
g = sns.countplot(x="NAME_CONTRACT_TYPE", data=application_train, hue="TARGET", order=name_contract_type.index, palette='viridis')
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Contract Type in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Contract Type", fontsize=20)

# %%
name_income_type = application_train["NAME_INCOME_TYPE"].value_counts()

trace = go.Pie(
    labels=name_income_type.index,
    values=name_income_type,
    hole= 0.5
)
data = [trace]

layout = go.Layout(
    title = "Income Source of the Applicants",
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
g = sns.countplot(x="NAME_INCOME_TYPE", data=application_train, hue="TARGET", order=name_income_type.index, palette='magma')
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Income sources in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Income Type", fontsize=20)

# %%
t = application_train[["NAME_INCOME_TYPE","TARGET"]].groupby(["NAME_INCOME_TYPE"]).mean().sort_values(by='TARGET', ascending=False)

plt.figure(figsize=(15,8))
sns.set(font_scale = 2)
sns.set_style('whitegrid')
g = sns.barplot(x=t.index.ravel(), y=t.values.ravel())
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_xlabel('Income Sources', fontsize=25)
g.set_title("Percent of not repayed loans per Income Source\n", fontsize=30)

# %%
name_family_status = application_train["NAME_FAMILY_STATUS"].value_counts()

trace = go.Pie(
    labels=name_family_status.index,
    values=name_family_status,
    hole= 0.5
)
data = [trace]

layout = go.Layout(
    title = "Family Status of Applicants",
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x="NAME_FAMILY_STATUS", data=application_train, hue="TARGET", order=name_family_status.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Family Status in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Family Status", fontsize=20)

# %%
occupation_type = application_train["OCCUPATION_TYPE"].value_counts()

plt.figure(figsize=(15,8))
sns.set(font_scale = 2)
sns.set_style('whitegrid')
g = sns.countplot("OCCUPATION_TYPE", data=application_train, order=occupation_type.index)
g.set_xticklabels(occupation_type.index, rotation=-85)
g.set_xlabel('Occupation', fontsize=25)
g.set_title("Occupation of Applicants who applied for loan\n", fontsize=30)

# %%
trace = go.Bar(
    x=occupation_type.index,
    y=occupation_type,
)
data = [trace]

layout = go.Layout(
    title = "Occupation of Applicants who applied for loan",
    xaxis=dict(
        title='Occupation',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    yaxis=dict(
        title='Count',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x="OCCUPATION_TYPE", data=application_train, hue="TARGET", order=occupation_type.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Occupation in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Occupation Type", fontsize=20)

# %%
flag_own_car = application_train["FLAG_OWN_CAR"].value_counts()

trace = go.Pie(
    labels=flag_own_car.index,
    values=flag_own_car,
    hole= 0.5
)
data = [trace]

layout = go.Layout(
    title = "Has own car",
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
flag_own_realty = application_train["FLAG_OWN_REALTY"].value_counts()

trace = go.Pie(
    labels=flag_own_realty.index,
    values=flag_own_realty,
    hole= 0.5
)
data = [trace]

layout = go.Layout(
    title = "Has own house",
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
name_education_type = application_train["NAME_EDUCATION_TYPE"].value_counts()

trace = go.Pie(
    labels=name_education_type.index,
    values=name_education_type,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Education level of Applicants"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x="NAME_EDUCATION_TYPE", data=application_train, hue="TARGET", order=name_education_type.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("Education level in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Education level", fontsize=20)

# %%
name_housing_type = application_train["NAME_HOUSING_TYPE"].value_counts()

trace = go.Pie(
    labels=name_housing_type.index,
    values=name_housing_type,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="House Type"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x="NAME_HOUSING_TYPE", data=application_train, hue="TARGET", order=name_housing_type.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-75)
g.set_title("House Type in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("\nHouse Type", fontsize=20)

# %%
organization_type = application_train["ORGANIZATION_TYPE"].value_counts()[:25]

plt.figure(figsize=(18,8))
sns.set(font_scale=1.25)
sns.set_style('whitegrid')
g = sns.countplot("ORGANIZATION_TYPE", data=application_train, order=organization_type.index)
g.set_xticklabels(organization_type.index, rotation=-90)
g.set_xlabel('Organization Type', fontsize=20)
g.set_title("Type of Organizations who applied of loan\n", fontsize=25)

# %%
plt.figure(figsize=(15,8))
sns.set(font_scale=1.25)
sns.set_style('whitegrid')
g = sns.countplot(x="ORGANIZATION_TYPE", data=application_train, hue="TARGET", order=organization_type.index)
g.set_xticklabels(g.get_xticklabels(), rotation=-90)
g.set_title("Organization Type in terms of loan was repayed or not\n", fontsize=25)
g.set_xlabel("Organization Type", fontsize=20)

# %%
previous_name_contract_type = previous_application["NAME_CONTRACT_TYPE"].value_counts()

trace = go.Pie(
    labels=previous_name_contract_type.index,
    values=previous_name_contract_type,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Contract Type of previous application"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
previous_weekday_process_start = previous_application["WEEKDAY_APPR_PROCESS_START"]

plt.figure(figsize=(15,8))
sns.set(font_scale=1.25)
sns.set_style('whitegrid')
g = sns.countplot(previous_weekday_process_start, order=previous_weekday_process_start.value_counts().index, palette='magma')
g.set_xlabel("\nDay of the Week", fontsize=15)
g.set_title("Day of the Week that clients applied in the previous application\n", fontsize=25)

# %%
previous_name_cash_loan_purpose = previous_application["NAME_CASH_LOAN_PURPOSE"].value_counts()[:5]

plt.figure(figsize=(15,8))
sns.set(font_scale=2)
sns.set_style('whitegrid')
g = sns.barplot(previous_name_cash_loan_purpose.index, (previous_name_cash_loan_purpose/previous_name_cash_loan_purpose.sum())*100, palette='viridis')
g.set_xticklabels(g.get_xticklabels(), rotation=-60)
g.set_title("Top 5 Purpose of loan in the previous application\n", fontsize=25)
g.set_ylabel("Percent %\n", fontsize=20)

# %%
name_contract_status = previous_application["NAME_CONTRACT_STATUS"].value_counts()

trace = go.Pie(
    labels=name_contract_status.index,
    values=name_contract_status,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Contract Status of previous application"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
name_payment_type = previous_application["NAME_PAYMENT_TYPE"].value_counts()

trace = go.Pie(
    labels=name_payment_type.index,
    values=name_payment_type,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Payment Type of previous application"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
code_reject_reason = previous_application["CODE_REJECT_REASON"].value_counts()

trace = go.Pie(
    labels=code_reject_reason.index,
    values=code_reject_reason,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Reason's code of previous application rejection"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
name_client_type = previous_application["NAME_CLIENT_TYPE"].value_counts()
    
trace = go.Pie(
    labels=name_client_type.index,
    values=name_client_type,
    hole=0.5
)
data = [trace]

layout = go.Layout(
    title="Client Type of previous application"
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
from sklearn.preprocessing import LabelEncoder

application_train.dtypes.value_counts()

# %%
application_train.select_dtypes('object').apply(pd.Series.nunique)

# %%
#application_train = pd.read_csv('../input/application_train.csv')
#application_test = pd.read_csv('../input/application_test.csv')

# %%
label_encoder = LabelEncoder()
label_encoder_count = 0

for col in application_train:
    if application_train[col].dtype == 'object':
        if len(list(application_train[col].unique())) <= 2:
            # Train on the training data
            label_encoder.fit(application_train[col])
            # Transform both training and testing data
            application_train[col] = label_encoder.transform(application_train[col])
            application_test[col] = label_encoder.transform(application_test[col])
            
            label_encoder_count +=1
print('%d columns were label encoded.' % label_encoder_count)

# %%
# one-hot encoding of categorical variables
application_train = pd.get_dummies(application_train)
application_test = pd.get_dummies(application_test)

# %%
application_train.shape, application_test.shape

# %%
train_target = application_train['TARGET']

application_train, application_test = application_train.align(application_test, join='inner', axis=1)

# %%
application_train.shape, application_test.shape

# %%
application_train['TARGET'] = train_target
application_train['DAYS_BIRTH'] = abs(application_train['DAYS_BIRTH'])
corr = application_train.corr()

# %%
corr.nlargest(5, 'TARGET')['TARGET']

# %%
cols = list(corr.nlargest(15, 'TARGET')
            .index) + \
       list(corr.nsmallest(15, 'TARGET')
            .sort_values(by='TARGET', ascending=False)
            .index)

plt.figure(figsize=(15,9))
sns.set(font_scale=1)
sns.heatmap(corr.loc[cols,cols], 
            linewidth=0.01, 
            annot=True, 
            fmt='.2f', 
            annot_kws={'size':8})

# %%
plt.figure(figsize=(15,9))
sns.set(font_scale=1.25)
sns.set_style('whitegrid')
g = sns.countplot(application_train['DAYS_BIRTH']/365, palette='magma', order=np.arange(20,72,2))
g.set_xlabel("\nAge in years", fontsize=15)
g.set_title("Age Distribution\n", fontsize=25)

# %%
df_repayed = application_train[application_train['TARGET']==0]
df_not_repayed = application_train[application_train['TARGET']==1]
plt.figure(figsize=(15,9))
plt.title("Distribution of Ages in terms of repaid loans or not\n", fontsize=25)
sns.kdeplot(df_not_repayed["DAYS_BIRTH"]/365, shade=True, label='Not repayed')
sns.kdeplot(df_repayed["DAYS_BIRTH"]/365, shade=True, label='Repayed')
plt.xlabel("Age in years")
plt.ylabel("Density")

# %%
age_data = application_train.loc[:,['TARGET', 'DAYS_BIRTH']]
age_data['YEARS_BIRTH'] = age_data['DAYS_BIRTH'] / 365

age_data['YEARS_BINNED'] = pd.cut(age_data['YEARS_BIRTH'], bins = np.arange(20, 75,5))
age_data.head()

# %%
age_groups = age_data.groupby('YEARS_BINNED').mean()['TARGET']
plt.figure(figsize=(15,8))
sns.set(font_scale = 2)
sns.set_style('whitegrid')
g = sns.barplot(x=age_groups.index, y=age_groups.values*100)
g.set_xticklabels(g.get_xticklabels(), rotation=75)
g.set_xlabel('Age Groups', fontsize=25)
g.set_title("Percent of not repayed loans per Age Group\n", fontsize=30)

# %%
plt.figure(figsize=(15,9))
plt.title("Distribution of EXT_SOURCE_3 in terms of repaid loans or not\n", fontsize=25)
sns.kdeplot(df_not_repayed["EXT_SOURCE_3"].dropna(), shade=True, label='Not repayed')
sns.kdeplot(df_repayed["EXT_SOURCE_3"].dropna(), shade=True, label='Repayed')
plt.xlabel("EXT_SOURCE_3")
plt.ylabel("Density")
