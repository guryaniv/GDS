# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd

main_file_path = '../input/house-prices-advanced-regression-techniques/train.csv' # this is the path to the Iowa data that you will use
test_file_path = '../input/house-prices-advanced-regression-techniques/test.csv' # this is the path to the Iowa data that you will use
data = pd.read_csv(main_file_path)
test = pd.read_csv(test_file_path)

y = data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]
test_X = test[features]

model = RandomForestRegressor()
model.fit(X, y)
prediction = model.predict(test_X)

my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': prediction})
my_submission.to_csv('submission.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd

main_file_path = '../input/house-prices-advanced-regression-techniques/train.csv' # this is the path to the Iowa data that you will use
data = pd.read_csv(main_file_path)

y = data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

model = RandomForestRegressor()
model.fit(train_X, train_y)
prediction = model.predict(val_X)
print(mean_absolute_error(val_y, prediction))

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd


def get_mae(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)


main_file_path = '../input/house-prices-advanced-regression-techniques/train.csv' # this is the path to the Iowa data that you will use
data = pd.read_csv(main_file_path)

y = data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 25, 40, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd


main_file_path = '../input/house-prices-advanced-regression-techniques/train.csv' # this is the path to the Iowa data that you will use
data = pd.read_csv(main_file_path)

y = data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

iowa_model = DecisionTreeRegressor()

iowa_model.fit(train_X, train_y)

val_predictions = iowa_model.predict(val_X)

print(mean_absolute_error(val_y, val_predictions))

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

main_file_path = '../input/house-prices-advanced-regression-techniques/train.csv' # this is the path to the Iowa data that you will use
data = pd.read_csv(main_file_path)

iowa_sale_price = data.SalePrice
print(iowa_sale_price.head())
print('\n')

interest_variables = ['Id', 'SalePrice']
two_vars_data = data[interest_variables]
print(two_vars_data.describe())
print('\n')

y = data.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = data[features]

iowa_model = DecisionTreeRegressor()
iowa_model.fit(X, y)

print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(iowa_model.predict(X.head()))
