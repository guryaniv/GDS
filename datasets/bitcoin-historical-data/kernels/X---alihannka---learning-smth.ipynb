# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import os
print(os.listdir("../input"))

# %%
data = pd.read_csv("../input/coinbaseUSD_1-min_data_2014-12-01_to_2018-06-27.csv") # importing dataset

# %%
data.info() # Info about dataset

# %%
data.drop(["Timestamp"],axis=1,inplace=True)

# %%
data.columns # Show Features

# %%
data.describe().iloc[:,:8] # Statistical datas of set.

# %%
data.tail(5) # last 5 samples to understand data and to compare.

# %%
data.head(10) # first 5 samples to understand and compare data.

# %%
data.corr() # correlation between datas. Closing 1 means positive corr, closing -1 means negative corr and closing 0 means no corr between them.

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()    #Visualization the corr.

# %%
data.plot(kind = "scatter",x="Volume_(BTC)",y="Volume_(Currency)",alpha=0.5,color="red")
plt.xlabel("Volume(BTC)")
plt.ylabel("Volume(Currency)")
plt.title("Volume Corr Between BTC And Currency")
plt.show() #scatterplot

# %%
data.Weighted_Price.plot(kind="hist",bins=50)
plt.show() # Histogram

# %%
data[(data["Low"]>10000.00) & (data["High"]>19826)] # Top Gainer 98 Currencies // Filtering Data
