# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
train=pd.read_csv('../input/train.tsv', sep='\t', encoding='utf-8')
test=pd.read_csv('../input/test.tsv', sep='\t', encoding='utf-8')

# %%
train.head()

# %%
test.head()

# %%
train.shape

# %%
test.shape

# %% [markdown]
# **So, ^^ from the data. My upcomming Approach will be :
#     1. after cleaning (lowercase->tokenizing->stopwords+punctuation removal->stemming(may be :O))
#     category name,
#     make a feature set of category name and then do encoding stuffs :P  That will prepare
#     our first feature set
#     2.Doing above with item description + POS tagging to extract sentimental words will
#     prepare our second feature set.
#     3.Now , NaN should be encoded with -1 or some values other than brands encoded values
#     to to distinguish brand items , but keep in mind not necessarily it will work,as some
#     brands might be missing rather than being unbranded item, so :) that makes our third
#     feature set.
#     ummmm, i think it will be good to start our journey.  :)**
