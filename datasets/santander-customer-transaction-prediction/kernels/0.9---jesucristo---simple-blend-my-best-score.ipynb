# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
s1 = pd.read_csv('../input/santander-magic-lgb/submission.csv')
s1.head()

# %%
s2 = pd.read_csv('../input/myblend000/simple_blend.csv')
s2.head()

# %%
s2 = pd.read_csv('../input/myblend000/simple_blend.csv')
s2.head()

# %%
s3 = pd.read_csv('../input/30-lines-starter-solution-fast/submission.csv')
s3.head()

# %%
pd.concat([s1['ID_code'], s1['target'], s2['target'], s3['target']],axis=1).head()

# %%
submission = pd.read_csv('../input/santander-customer-transaction-prediction/sample_submission.csv')

# %%
# Update. Thanks Jie Wu and Ilu
submission['target'] = 0.15*s1['target']+0.7*(s2['target'])+0.15*s3['target']
submission.to_csv('blend_submission.csv', index=False)
submission.head()
