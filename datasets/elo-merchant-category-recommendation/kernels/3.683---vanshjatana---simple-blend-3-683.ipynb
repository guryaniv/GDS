# %%
import numpy as np 
import pandas as pd 
df1  = pd.read_csv('../input/blend-public-score1/sub1.csv')
df2 = pd.read_csv('../input/blend-public-score1/sub2.csv')
df1['target'] = .56*df1['target'] + .5*df2['target']
df1.head()

# %%
df1.to_csv('ens.csv',index=False)
