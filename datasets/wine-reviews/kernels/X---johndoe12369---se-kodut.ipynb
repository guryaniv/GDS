# %% [markdown]
# **Wine reviews**
#
# Rimante Valancauskaite ja Hans Henrik Viinalass
#
# Andmed võtsime Kaggle'ist saadud Wine Reviews andmebaasist[1].
#
# [1] Kaggle, "Wine Reviews" https://www.kaggle.com/zynicide/wine-reviews

# %% [markdown]
# **Uurimisküsimused**
#
# 1. Kuidas sõltub veini kvaliteet hinnast? (Scatterplot)
# 2. Mis riigi veini kvaliteedi keskmine on kõrgeim? (Groupby)
# 3. Kui palju kvaliteedipunkte anti? (Histogramm) / Mis kvaliteedipunkte anti kõige rohkem? / Kuhu vahemikku jäävad enamus antud kvaliteedipunktidest?
# 4. Mida saab andmete põhjal teada kõige kallimast veinist?

# %%
import numpy as np
import pandas as pd

from subprocess import check_output
check_output(["ls", "../input"]).decode("utf8")

# %matplotlib inline
pd.set_option('display.max_rows', 20)

df = pd.read_csv("../input/winemag-data-130k-v2.csv")
#df["country"].value_counts().head(10)

# %% [markdown]
# **10 kõige rohkemate arvustustega riiki:**

# %%
#ARVUSTUSTE HULK RIIKIDE KAUPA#
df["country"].value_counts().head(10)

# %% [markdown]
# **Kuidas sõltub veini kvaliteet hinnast?**

# %%
# VEINI HINNA JA KVALITEEDI SUHE
df.plot.scatter("points", "price", alpha = 0.2);

# %% [markdown]
# **Mis riigi veinikvaliteedi keskmine on kõrgeim?**

# %%
#TOP 20 KÕRGEIMA VEINIKVALITEEDIGA RIIKI"
df2=pd.DataFrame(df.groupby("country")["points"].mean())
df2.sort_values("points", ascending = 0)

df2["max"]=pd.DataFrame(df.groupby("country")["points"].max())
df2["min"]=pd.DataFrame(df.groupby("country")["points"].min())
df2["review count"]=df["country"].value_counts()
df2.sort_values("points", ascending = 0).head(20)

# %% [markdown]
# ** Kuhu vahemikku jäävad enamus antud kvaliteedipunktidest?**

# %%
# ARVUSTUSTE KVALITEEDIPUNKTIDE KOGUSED
df.points.plot.hist(bins = 20, grid = 0, rwidth = 0.8);

# %%
# TOP 10 KÕIGE KALLIMAT VEINI
(df[["country", "points", "title", "price", "province", "winery", "description"]]
 .sort_values("price", ascending = 0)).head(10)

# %% [markdown]
# **Kõige kallim vein on Château les Ormes Sorbet 2013 Médoc hinnaga 3300 USD.**

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url = "http://avis-vin.lefigaro.fr/var/img/480/119905-650x330-8-chateaux-de-l-appellation-medoc-etaient-presents-dont-le-chateau-les-ormes-sorbet.jpg")
