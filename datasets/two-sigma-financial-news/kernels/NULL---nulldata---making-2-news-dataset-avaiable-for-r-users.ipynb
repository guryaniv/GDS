# %% [markdown]
# ### Loading the Python Package

# %%
from kaggle.competitions import twosigmanews
env = twosigmanews.make_env()

(market_train_df, news_train_df) = env.get_training_data()

# %% [markdown]
# ### Checking if the data is loaded

# %%
market_train_df.head()

# %%
news_train_df.head()

# %% [markdown]
# ### Let's get the dimensions of the dataframe

# %%
market_train_df.shape

# %%
news_train_df.shape

# %% [markdown]
# Writing both the files finishes all the space and results in  this error `No space left on device` so one at at time!

# %%
import pandas as pd
#market_train_df.to_csv("market_train_df.csv")
news_train_df.to_csv("news_train_df.csv")
