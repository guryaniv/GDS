# %% [markdown]
# # Introduction
# **This will be your workspace for Kaggle's Machine Learning education track.**
#
# You will build and continually improve a model to predict housing prices as you work through each tutorial.  Fork this notebook and write your code in it.
#
# The data from the tutorial, the Melbourne data, is not available in this workspace.  You will need to translate the concepts to work with the data in this notebook, the Iowa data.
#
# Come to the [Learn Discussion](https://www.kaggle.com/learn-forum) forum for any questions or comments.
#
# # Write Your Code Below

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
from sklearn.ensemble import RandomForestRegressor # library for Random Forest model

train_file_path = '../input/train.csv' # store file path
train = pd.read_csv(train_file_path) # read the training data
print(train.describe()) # print data
print(train.columns) # print name of columns 

y = train.SalePrice # set single column salePrice as target column
predic_cols = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
train_X =  train[predic_cols] # set list of columns predic_cols as predictors

forest_model = RandomForestRegressor() # create random forest model
forest_model.fit(train_X, y) # train the model using predictors and target values

test = pd.read_csv('../input/test.csv') # Read the test data
# Treat the test data in the same way as training data. In this case, pull same columns.
test_X = test[predic_cols]
predic_vals = forest_model.predict(test_X) # make predictions using the model and test values
print("Making predictions for the following 5 houses:") 
print(train_X.head()) 
print("The predictions are")
print(predic_vals) # print predicted values

submission_file = pd.DataFrame({'Id': test.Id, 'SalePrice': predic_vals}) # storing the predictions in a submission file
submission_file.to_csv('submission_file.csv', index=False) # using pandas' to_csv method to write a submission file

# %%
import pandas as pd 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
y = data.SalePrice
iowa_preds = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
X = data[iowa_preds]
train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 0)

forest_model = RandomForestRegressor()
forest_model.fit(train_X, train_y)
iowa_pred_val = forest_model.predict(val_X)
print(mean_absolute_error(val_y, iowa_pred_val))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)

iowa_file_path = '../input/train.csv'
data = pd.read_csv(iowa_file_path) 
y = data.SalePrice
iowa_preds = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
X = data[iowa_preds]

train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 0)

for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
train_X, val_X,train_y, val_y = train_test_split(X, y, random_state=0)
iowa_model = DecisionTreeRegressor()
iowa_model.fit(train_X, train_y)
val_predic = iowa_model.predict(val_X)
print(mean_absolute_error(val_y, val_predic))

# %%
# validation using the same data that was used to build the model
# also called in-sample scores
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
print(data.describe())
y = data.SalePrice
data_predic = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
X = data[data_predic]
iowa_model = DecisionTreeRegressor()
iowa_model.fit(X, y)
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(iowa_model.predict(X.head()))
predic_prices = iowa_model.predict(X)
mean_absolute_error(y, predic_prices)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
print(data.describe())
# set sale price as prediction target
y = data.SalePrice
# set the other columns as predictors
data_predic = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
X = data[data_predic]
# Define model
iowa_model = DecisionTreeRegressor()
# Fit model
iowa_model.fit(X, y)
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(iowa_model.predict(X.head()))

# %%
import pandas as pd

main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
# selecting multiple comlumns together
rel_cols = ['Alley','Street']
data_multiple = data[rel_cols]
print(data_multiple.describe())

# %%
import pandas as pd

main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
# selecting single column
data_alley = data.Alley
print(data_alley.head())
# print the first few lines of the column

# %%
import pandas as pd

main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
print(data.columns)
# display all the columns present in the Dataframe

# %%
import pandas as pd

data_file_path = '../input/train.csv'
# store the file path
data = pd.read_csv(data_file_path)
# read the file present at the path stored
print(data.describe())
# print the contents o fthe DataFrame-'data'

# %%
import pandas as pd

main_file_path = '../input/train.csv'
# store file path
data = pd.read_csv(main_file_path)
# read the file present at the path stored
print('hello world')
# print hello world
