# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# **CareerVillage.org is a nonprofit that crowdsources career advice for underserved youth. Founded in 2011 in four classrooms in New York City, the platform has now served career advice from 25,000 volunteer professionals to over 3.5M online learners. The platform uses a Q&A style similar to StackOverflow or Quora to provide students with answers to any question about any career.**

# %% [markdown]
# To date, 25,000 volunteers have created profiles and opted in to receive emails when a career question is a good fit for them.  To help students get the advice they need, the team at CareerVillage.org needs to be able to send the right questions to the right volunteers.
#
# ** objective: developing a method to recommend relevant questions to the professionals who are most likely to answer them.**

# %%
students = pd.read_csv('../input/students.csv')

# %%
students.head()

# %%
import matplotlib.pyplot as plt
students['students_location'].value_counts().head(15).plot.bar()
plt.title('Most frequently used Students Location ')
plt.xlabel('Location - State,Country')
plt.ylabel('Count')

# %%
professionals = pd.read_csv('../input/professionals.csv')

# %%
professionals.head()

# %%
import matplotlib.pyplot as plt
professionals['professionals_industry'].value_counts().head(15).plot.bar()
plt.title('Professionals Industry ')
plt.xlabel('Industry')
plt.ylabel('Count')

# %%
import matplotlib.pyplot as plt
professionals['professionals_headline'].value_counts().head(15).plot.bar()
plt.title('professionals_headline ')
plt.xlabel('Industry')
plt.ylabel('Count')

# %% [markdown]
# Most of the Professionals are from United States

# %%
import matplotlib.pyplot as plt
professionals['professionals_location'].value_counts().head(15).plot.bar()
plt.title('Professionals Location ')
plt.xlabel('Location - State,Country')
plt.ylabel('Count')

# %%
questions = pd.read_csv('../input/questions.csv')

# %%
questions.head()

# %% [markdown]
# **QUESTIONS TITLE**

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
words = ' '.join(questions['questions_title'])
wordcloud = WordCloud(stopwords=STOPWORDS,max_words=500,
                      background_color='white',min_font_size=6,
                      width=3000,collocations=False,
                      height=2500
                     ).generate(words)
plt.figure(1,figsize=(20, 20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **questions_body**

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
words = ' '.join(questions['questions_body'])
wordcloud = WordCloud(stopwords=STOPWORDS,max_words=500,
                      background_color='black',min_font_size=6,
                      width=3000,collocations=False,
                      height=2500
                     ).generate(words)
plt.figure(1,figsize=(20, 20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
wordcloud_words = wordcloud.words_
s  = pd.Series(wordcloud_words,index=wordcloud_words.keys())
s.head(5)

# %%
answers = pd.read_csv('../input/answers.csv')

# %%
answers.head()

# %%
answers['answers_body'][0]

# %%
answers['answers_question_id'][0]

# %%
questions['questions_id'][0]

# %%
questions['questions_body'][0]

# %%
quandata = pd.merge(questions,answers, left_on = 'questions_id', right_on = 'answers_question_id')

# %%
quandata.head()

# %%
prof = quandata['answers_author_id'].value_counts().head(10)

# %%
prof.colnames = ['professionals_id','count']
prof

# %%
professionals[professionals['professionals_id']=='36ff3b3666df400f956f8335cf53e09e']

# %% [markdown]
# **A Professional from Cleveland,Ohio - Mental Health Care Industry has answered many questions (1710) since  October 2015**

# %%
profmo = quandata[quandata['answers_author_id']=='36ff3b3666df400f956f8335cf53e09e']['questions_title']

# %% [markdown]
# Questions answered of the Professional - '36ff3b3666df400f956f8335cf53e09e'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
words = ' '.join(profmo)
wordcloud = WordCloud(stopwords=STOPWORDS,max_words=500,
                      background_color='black',min_font_size=6,
                      width=3000,collocations=False,
                      height=2500
                     ).generate(words)
plt.figure(1,figsize=(20, 20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
wordcloud_words = wordcloud.words_
s  = pd.Series(wordcloud_words,index=wordcloud_words.keys())
s.head(5)

# %%
comments = pd.read_csv('../input/comments.csv')

# %%
comments.head()

# %%
emails = pd.read_csv('../input/emails.csv')

# %%
emails.head()

# %% [markdown]
# **MORE TO COME STAY TUNED**
