# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
train = pd.read_json('../input/train.json')
train.head()

# %%
train.info()

# %%
test = pd.read_json('../input/test.json')
test.head()

# %%
train['band_1'].shape

# %%
test['band_1'].shape

# %%
train_image1_band_1 = np.reshape(train['band_1'][0],(75,75))
train_image1_band_2 = np.reshape(train['band_2'][0],(75,75))


plt.subplot(121)
plt.imshow(train_image1_band_1)
plt.subplot(122)
plt.imshow(train_image1_band_2)

plt.show()

print(train['is_iceberg'][0])

# %%
train_image5_band_1 = np.reshape(train['band_1'][5],(75,75))
train_image5_band_2 = np.reshape(train['band_2'][5],(75,75))


plt.subplot(121)
plt.imshow(train_image5_band_1)
plt.subplot(122)
plt.imshow(train_image5_band_2)

plt.show()

print(train['is_iceberg'][5])
