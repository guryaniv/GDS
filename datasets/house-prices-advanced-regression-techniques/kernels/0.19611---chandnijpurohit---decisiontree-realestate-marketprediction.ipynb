# %% [markdown]
# Sample of code below.

# %%
import pandas as pd

main_file_path = '../input/train.csv'
data = pd.read_csv(main_file_path)
#Size of data
print ('Rows,Columns: ',data.shape)
#Show Statistical details about numerical features 
print (data.describe())
#Show Input Types
print (data.info())

# %%
column_set = data.columns
print (sorted(column_set))

y = data.SalePrice
Data_TwoVariables = ['LotArea', 'YearRemodAdd']
X = data[Data_TwoVariables]
X.describe()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
predictors = ['LotArea',
'YearBuilt',
'1stFlrSF',
'2ndFlrSF',
'FullBath',
'BedroomAbvGr',
'TotRmsAbvGrd']
X = data[predictors]
y = data.SalePrice
# model = DecisionTreeRegressor()
# model.fit(data[predictors],y)
# y_predicted = model.predict(data[predictors])
# print (y_predicted)

# %%
def BasicRegressors(model_name,X_train,y_train,X_test,y_test):
    if model_name=='DecisionTreeRegressor':      
        model = model_name(max_leaf_nodes=mx)
    else:
        model = model_name()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print (mae(y_pred,y_test))
    return model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)
for mx in [5,50,500,5000]:
    BasicRegressors(DecisionTreeRegressor,X_train,y_train,X_test,y_test)

# %%
mymodel= BasicRegressors(RandomForestRegressor,X_train,y_train,X_test,y_test)
test_data = pd.read_csv('../input/test.csv')
x_test_data = test_data[predictors]
o = mymodel.predict(x_test_data)
otp = pd.DataFrame({'Id':test_data.Id,'SalePrice':o})
otp.to_csv('mySubmission.csv',index=False)

# %%
# #BasicRegressors(DecisionTreeRegressor,X_train,y_train,X_test,y_test)
# o = BasicRegressors(RandomForestRegressor,X_train,y_train,X_test,y_test)
# otp = pd.DataFrame({'Id':data.Id,'SalePrice':o})
# otp.to_csv('mySubmission.csv',index=False)

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error as mae
# X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# for mx in [5,50,500,5000]:
#     BasicRegressors(DecisionTreeRegressor,X_train,y_train,X_test,y_test)
# #     model = DecisionTreeRegressor(max_leaf_nodes=mx)
# #     model.fit(X_train,y_train)
# #     y_test_predicted = model.predict(X_test)    
# #     print (mae(y_test_predicted,y_test))
# #     print (y_test_predicted)
