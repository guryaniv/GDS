# %% [markdown]
# # Career Recommendation
# ----
# What is Recommendation ?
# Recommendation systems are  ML system, which help in getting relevent information or suggestion
#
# - There are two Type
#
# **1. Content-Based**
#
# **2. Collaborative Filtering**

# %% [markdown]
# ## ***Import libraries***

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)  
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS
import nltk

# %% [markdown]
# ## ***Load dataset***

# %%
df_professionals = pd.read_csv("../input/professionals.csv",)
df_tag_users = pd.read_csv("../input/tag_users.csv")
df_students = pd.read_csv("../input/students.csv",index_col = "students_id", parse_dates = ['students_date_joined'])
df_tag_questions = pd.read_csv("../input/tag_questions.csv")
df_groups = pd.read_csv("../input/groups.csv")
df_emails = pd.read_csv("../input/emails.csv")
df_group_memberships = pd.read_csv("../input/group_memberships.csv")
df_answer = pd.read_csv("../input/answers.csv")
df_comments = pd.read_csv("../input/comments.csv")
df_matches = pd.read_csv("../input/matches.csv")
df_questions = pd.read_csv("../input/questions.csv")
df_school_memberships = pd.read_csv("../input/school_memberships.csv")

# %% [markdown]
# ### Show all the feature columns for every dataset

# %%
print(df_students.columns)
print("professionals Columns : {} ".format(df_professionals.columns))
print("tag_users Columns : {} ".format(df_tag_users.columns))
print("tag_questions Columns : {} ".format(df_tag_questions.columns))
print("groups Columns : {} ".format(df_groups.columns))
print("emails.columns(),  {} ".format(df_emails.columns))
print("group_memberships.columns(),  {} ".format(df_group_memberships.columns))
print("answer Columns : {} ".format(df_answer.columns))
print("comments   Columns : {} ".format(df_comments.columns))
print("matches Columns : {} ".format(df_matches.columns))
print("questions Columns : {} ".format(df_questions.columns))
print("school_memberships Columns :  {} ".format(df_school_memberships.columns))

# %%
print("students.shape,  {} ".format(df_students.shape ))
print("professionals   Shape : {} ".format(df_professionals.shape))
print("tag_users   Shape : {} ".format(df_tag_users.shape))
print("tag_questions   Shape : {} ".format(df_tag_questions.shape))
print("groups   Shape : {} ".format(df_groups.shape))
print("emails.shape,  {} ".format(df_emails.shape, ))
print("group_memberships.shape,  {} ".format(df_group_memberships.shape))
print("answer   Shape : {} ".format(df_answer.shape))
print("comments     Shape : {} ".format(df_comments.shape, ))
print("matches   Shape : {} ".format(df_matches.shape))
print("questions   Shape : {} ".format(df_questions.shape))
print("school_memberships.shape {} ".format(df_school_memberships.shape))

# %%
df_questions.head()

# %%
ax=sns.countplot(data=df_emails, x='emails_frequency_level')
ax.set_xticklabels(rotation=60, labels=ax.get_xticklabels())
# df_emails.head()

# %%
df_professionals.head()

# %%
df_questions.head()
