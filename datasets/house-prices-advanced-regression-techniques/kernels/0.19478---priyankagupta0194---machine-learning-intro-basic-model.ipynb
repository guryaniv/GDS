# %% [markdown]
# # Introduction
# **My workspace for Kaggle's Machine Learning course**
#
#
# # Write Your Code Below

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

main_file_path = '../input/train.csv' # this is the path to the Iowa data that is used
data = pd.read_csv(main_file_path)
y = data.SalePrice
x = data[['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]
#print(data.describe())
#print(data.columns)
#print(two_columns_data.describe())
#x_train, x_val, y_train, y_val = train_test_split(x, y, random_state = 0)
#def get_mae(max_leaf_nodes, x_train, x_val, y_train, y_val):
#    my_model = DecisionTreeRegressor(max_leaf_nodes = max_leaf_nodes, random_state = 0)
#    my_model.fit(x_train, y_train)
#    prediction = my_model.predict(x_val)
#    error = mean_absolute_error(y_val, prediction)
#    return (error)
    
#for max_leaf_nodes in [5, 50, 500, 5000]:
#    error = get_mae(max_leaf_nodes, x_train, x_val, y_train, y_val)
#    print("Leaf Nodes: %d\tError: %f" %(max_leaf_nodes, error))
forest_model = RandomForestRegressor()
forest_model.fit(x, y)

test_data = pd.read_csv('../input/test.csv')
x_test = test_data[['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]
prediction = forest_model.predict(x_test)

#print(prediction)
my_submission = pd.DataFrame({'Id' : test_data.Id, 'SalePrice' : prediction})
my_submission.to_csv('submission.csv', index = False)

# %% [markdown]
# **If you have any questions or hit any problems, come to the [Learn Discussion](https://www.kaggle.com/learn-forum) for help. **
